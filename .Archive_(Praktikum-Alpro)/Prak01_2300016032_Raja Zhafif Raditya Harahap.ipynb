# %%
# Praktikum Algoritma Pemprograman Pertemuan Pertama 
# Nama : Raja Zhafif Raditya Harahap
# Nim : 2300016032

import math;

# Definiting Funtion Code Dibawah Sini
    
# Function Kalkulator Persamaan Kuadrat
def PersamaanKuadrat():
    # Title Start Display Kode 
    print("=============================================="); 
    print("Kalkulator Persamaan Kuadrat ax^2 + bx + c = 0");
    print("=============================================="); 
    print(""); 
    
    # Masukkan nilai a, b, dan c dari persamaan kuadrat
    a = float(input("Masukkan Variable a = "));
    b = float(input("Masukkan Variable b = "));
    c = float(input("Masukkan Variable c = "));
    print("");
    
    # Rumus Menghitung Diskriminan
    diskriminan = (b**2) - (4*a*c);
    
    # Jika diskriminan positif, maka memiliki dua akar riil
    if diskriminan > 0:
        akar1 = (-b + math.sqrt(diskriminan)) / (2*a);
        akar2 = (-b - math.sqrt(diskriminan)) / (2*a);
    
    # Jika diskriminan nol, maka memiliki satu akar ganda
    elif diskriminan == 0:
        akar = -b / (2*a);
    
    # Jika diskriminan negatif, maka memiliki dua akar kompleks konjugat
    else:
        bagianReal = -b / (2*a);
        bagianImaginary = math.sqrt(abs(diskriminan)) / (2*a);
        akar1 = complex(bagianReal, bagianImaginary);
        akar2 = complex(bagianReal, -bagianImaginary);

    # Cetak hasil
    print("=============================================="); 
    print("Akar pertama = ", akar1);
    print("Akar kedua = ", akar2);
    print("=============================================="); 
    print("");

# Function Menghitung Volume Tabung
def VolumeTabung():
    # Title Start Display Kode 
    print("=============================================="); 
    print("=          Kalkulator Volume Tabung          =");
    print("=============================================="); 
    print(""); 
    
    # Inputnya Volume Tabung
    r = float(input("Masukan Jari Jari Tabung = "));
    h = float(input("Masukan Tinggi Tabung = "));
    
    #Rumus Volume Tabung
    V = math.pi * r**2 * h;
    
    # Cetak hasil
    print("=============================================="); 
    print("Volume Tabung Tersebut Adalah = ", V);
    print("=============================================="); 
    print("");

def LuasBelahKetupat():
    # Title Start Display Kode 
    print("=============================================="); 
    print("=       Kalkulator Luas Belah Ketupat        =");
    print("=============================================="); 
    print(""); 
    
    # Inputnya Luas Belah Ketupat
    a = float(input("Masukan Panjang Diagonal Pertama = "));
    b = float(input("Masukan Panjang Diagonal Kedua = "));
    
    # Rumus Luas Belah ketupat
    L = (a*b) / 2;
   
    # Cetak hasil
    print("=============================================="); 
    print("Luas Belah Ketupat Tersebut Adalah = ", L);
    print("=============================================="); 
    print("");

# Function Untuk Mengulang Setiap Kali Dijalankan
def LoopStart():
    # Pemanis Hanya Title Dari Kodenya Biar Keren
    print("===================================================");
    print("Praktikum Algoritma Pemprograman Pertemuan Pertama ");
    print("===================================================");
    print("=                    Pilihan                      =");
    print("===================================================");
    print("= 1 . Hitung Persamaan Kuadrat  ax^2 * bx * c = 0 =");
    print("= 2 . Hitung Luas Belah Ketupat                   =");
    print("= 3 . Hitung Volume Tabung                        =");
    print("= 4 . Untuk Keluar Kode                           =");
    print("===================================================");
    print("");
    print("Ketik Angka Dari Pilihan tersebut Untuk Menjalankan Kodenya");
    print("");

    pilihan = int(input("Masukan Pilihan Yang Ingin Dicoba = "));

    print(chr(27) + "[2J")
    if pilihan == 1:
        PersamaanKuadrat();
        LoopStart();
        
    elif pilihan == 2:
        LuasBelahKetupat();
        LoopStart();
        
    elif pilihan == 3:
        VolumeTabung();
        LoopStart();
        
    elif pilihan == 4:
        print("Terima Kasih Telah Mencoba Kode Saya -Japip");
        print("");
        
    else:
        print("Tolong Masukan Pilihan yang sesuai Diatas");
        print("");
        LoopStart();
        
#Inisiasi loop Pertama
LoopStart();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 import math;
#       8 #Inisiasi loop Pertama
# ----> 9 LoopStart();
#      12 # Definiting Funtion Code Dibawah Sini
#      13
#      14 # Function Kalkulator Persamaan Kuadrat
#      15 def PersamaanKuadrat():
#      16     # Title Start Display Kode
#
# NameError: name 'LoopStart' is not defined

# %%
def LuasBelahKetupat(a, b):
    # Rumus Luas Belah ketupat
    L = (a*b) / 2;
    print(L);
    
a = float(input("Masukan Panjang Diagonal Pertama = "));
b = float(input("Masukan Panjang Diagonal Kedua = "));
HitungBelahKetupat(a,b);

# %%
# Function Menghitung Volume Tabung
def VolumeTabung():
    # Inputnya
    r = float(input("Masukan Jari Jari Tabung = "));
    h = float(input("Masukan Tinggi Tabung = "));
    
    #Rumus Volume Tabung
    V = math.pi * r**2 * h;
    print(V);

VolumeTabung();

# %%
import math;

def HitungKuadrat(a, b, c):
    # Rumus Menghitung Diskriminan
    diskriminan = (b**2) - (4*a*c);
    
    # Jika diskriminan positif, maka memiliki dua akar riil
    if diskriminan > 0:
        akar1 = (-b + math.sqrt(diskriminan)) / (2*a);
        akar2 = (-b - math.sqrt(diskriminan)) / (2*a);
        return root1, root2;
    
    # Jika diskriminan nol, maka memiliki satu akar ganda
    elif diskriminan == 0:
        akar = -b / (2*a);
        return akar, akar;
    
    # Jika diskriminan negatif, maka memiliki dua akar kompleks konjugat
    else:
        bagianReal = -b / (2*a);
        bagianImaginary = math.sqrt(abs(diskriminan)) / (2*a);
        akar1 = complex(bagianReal, bagianImaginary);
        akar2 = complex(bagianReal, -bagianImaginary);
        return akar1, akar2;
    
# Buat Looping Setiap Kali Telah Dihitung
def PersamaanKuadrat():
    # Title Start Display Kode 
    print("=============================================="); 
    print("Kalkulator Persamaan Kuadrat ax^2 + bx + c = 0");
    print("=============================================="); 
    print(""); 
    
    # Masukkan nilai a, b, dan c dari persamaan kuadrat
    a = float(input("Masukkan Variable a = "));
    b = float(input("Masukkan Variable b = "));
    c = float(input("Masukkan Variable c = "));
    print("");

    # Panggil fungsi untuk menyelesaikan persamaan kuadrat
    akar1, akar2 = HitungKuadrat(a, b, c);

    # Cetak hasil
    print("=============================================="); 
    print("Akar pertama:", akar1);
    print("Akar kedua:", akar2);
    print("=============================================="); 
    print("");
    LoopStart();

LoopStart();
